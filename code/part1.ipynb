# %%
import torch
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git" --quiet
# !pip install --no-deps "xformers<0.0.29" "trl<0.9.0" peft accelerate bitsandbytes --quiet

from unsloth import FastLanguageModel
import time
import json
import re
import matplotlib.pyplot as plt
import pandas as pd
from statistics import mean
import gc

print(" Unsloth installation complete. Start the 365-question experiment")

# 365个问题
QUESTIONS = [
    {"question": "谁发明了电话？", "ground_truth": "亚历山大·格雷厄姆·贝尔"},
    {"question": "地球上最高的山峰是什么？", "ground_truth": "珠穆朗玛峰"},
    {"question": "光的速度大约是多少米每秒？", "ground_truth": "299792458"},
    {"question": "中国四大发明是什么？", "ground_truth": "造纸术、印刷术、火药、指南针"},
    {"question": "DNA的双螺旋结构是由谁发现的？", "ground_truth": "詹姆斯·沃森和弗朗西斯·克里克"},
    {"question": "Python编程语言是由谁创建的？", "ground_truth": "吉多·范罗苏姆"},
    {"question": "世界上最长的河流是哪一条？", "ground_truth": "尼罗河"},
    {"question": "爱因斯坦的著名方程是什么？", "ground_truth": "E=mc²"},
    {"question": "联合国的总部在哪里？", "ground_truth": "纽约"},
    {"question": "第一个登上月球的人是谁？", "ground_truth": "尼尔·阿姆斯特朗"},
    {"question": "谁提出了日心说？", "ground_truth": "尼古拉斯·哥白尼"},
    {"question": "第一次鸦片战争爆发于哪一年？", "ground_truth": "1840年"},
    {"question": "金的化学符号是什么？", "ground_truth": "Au"},
    {"question": "青霉素的发现者是谁？", "ground_truth": "亚历山大·弗莱明"},
    {"question": "古埃及最著名的金字塔是哪一座？", "ground_truth": "胡夫金字塔"},
    {"question": "牛顿第一运动定律又称什么定律？", "ground_truth": "惯性定律"},
    {"question": "日本偷袭珍珠港发生在哪一年？", "ground_truth": "1941年"},
    {"question": "人类基因组计划大致完成于哪一年？", "ground_truth": "2003年"},
    {"question": "光的折射定律的提出者是？", "ground_truth": "威里布罗德·斯涅尔"},
    {"question": "黑洞的边界被称为什么？", "ground_truth": "事件视界"},
    {"question": "孟德尔遗传实验中使用的主要植物是什么？", "ground_truth": "豌豆"},
    {"question": "第一次工业革命的核心发明是？", "ground_truth": "蒸汽机"},
    {"question": "古罗马的建立者传说中的人物是？", "ground_truth": "罗慕路斯"},
    {"question": "光合作用的主要产物是什么？", "ground_truth": "葡萄糖和氧气"},
    {"question": "蒸汽机的重要改良者是？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "法国大革命开始于哪一年？", "ground_truth": "1789年"},
    {"question": "量子论的提出者是？", "ground_truth": "马克斯·普朗克"},
    {"question": "马里亚纳海沟位于哪个大洋？", "ground_truth": "太平洋"},
    {"question": "谁发现了放射性现象？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "阿波罗11号登月飞船的名称是什么？", "ground_truth": "鹰号"},
    {"question": "文艺复兴运动起源于哪个国家？", "ground_truth": "意大利"},
    {"question": "元素周期表的发明者是？", "ground_truth": "德米特里·门捷列夫"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "莱特兄弟发明了什么？", "ground_truth": "飞机"},
    {"question": "互联网的前身是哪个项目？", "ground_truth": "ARPA网"},
    {"question": "谁提出了进化论？", "ground_truth": "查尔斯·达尔文"},
    {"question": "硅谷位于美国哪个州？", "ground_truth": "加利福尼亚州"},
    {"question": "诺贝尔奖的设立者是？", "ground_truth": "阿尔弗雷德·诺贝尔"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "第一次世界大战结束于哪一年？", "ground_truth": "1918年"},
    {"question": "万有引力常数G的近似值是多少？", "ground_truth": "6.67430 × 10^{-11}"},
    {"question": "谁是现代密码学之父？", "ground_truth": "克劳德·香农"},
    {"question": "世界上第一个计算机程序是由谁编写的？", "ground_truth": "阿达·洛芙莱斯"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊哲学三贤之一苏格拉底的学生是？", "ground_truth": "柏拉图"},
    {"question": "特洛伊战争传说中的希腊英雄是？", "ground_truth": "阿喀琉斯"},
    {"question": "第二次世界大战结束的具体日期是？", "ground_truth": "1945年9月2日"},
    {"question": "量子力学中薛定谔的著名方程是什么？", "ground_truth": "iħ ∂ψ/∂t = Ĥψ"},
    {"question": "古中国商朝的都城是哪里？", "ground_truth": "殷墟（安阳）"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "世界上最古老的大学是哪一所？", "ground_truth": "博洛尼亚大学"},
    {"question": "光电效应的解释者是？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "细菌的遗传物质是什么？", "ground_truth": "DNA"},
    {"question": "谁提出了大陆漂移学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "古希腊哲学家亚里士多德的学生是？", "ground_truth": "亚历山大大帝"},
    {"question": "第一次登上南极点的人是？", "ground_truth": "罗阿尔德·阿蒙森"},
    {"question": "元素周期表中原子序数为79的元素是什么？", "ground_truth": "金"},
    {"question": "谁发明了活字印刷术？", "ground_truth": "毕昇"},
    {"question": "相对论的提出者是谁？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "第二次世界大战开始于哪一年？", "ground_truth": "1939年"},
    {"question": "谁改良了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "古希腊三大哲学家是谁？", "ground_truth": "苏格拉底、柏拉图、亚里士多德"},
    {"question": "谁发现了万有引力？", "ground_truth": "艾萨克·牛顿"},
    {"question": "元素周期表中原子序数为1的元素是什么？", "ground_truth": "氢"},
    {"question": "谁发明了电灯？", "ground_truth": "托马斯·爱迪生"},
    {"question": "古埃及法老中最著名的是谁？", "ground_truth": "图坦卡蒙"},
    {"question": "谁提出了量子力学中的波粒二象性？", "ground_truth": "路易·德布罗意"},
    {"question": "第一次世界大战的导火索是什么事件？", "ground_truth": "萨拉热窝事件"},
    {"question": "谁是《物种起源》的作者？", "ground_truth": "查尔斯·达尔文"},
    {"question": "光合作用发生在植物的哪个细胞器？", "ground_truth": "叶绿体"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古中国秦朝的第一个皇帝是谁？", "ground_truth": "秦始皇"},
    {"question": "谁发明了电话的改进版本并实现商业化？", "ground_truth": "亚历山大·格雷厄姆·贝尔"},
    {"question": "水的化学式是什么？", "ground_truth": "H₂O"},
    {"question": "谁提出了基因理论？", "ground_truth": "格雷戈尔·孟德尔"},
    {"question": "文艺复兴时期最著名的画家是谁？", "ground_truth": "列奥纳多·达·芬奇"},
    {"question": "谁发现了青霉素？", "ground_truth": "亚历山大·弗莱明"},
    {"question": "太阳系中最大的行星是哪一颗？", "ground_truth": "木星"},
    {"question": "谁是《哈姆雷特》的作者？", "ground_truth": "威廉·莎士比亚"},
    {"question": "原子弹的原理基于什么反应？", "ground_truth": "核裂变"},
    {"question": "谁发现了电磁感应？", "ground_truth": "迈克尔·法拉第"},
    {"question": "古罗马最著名的角斗士是谁？", "ground_truth": "斯巴达克斯"},
    {"question": "谁提出了大数据概念？", "ground_truth": "克利夫·斯托尔"},
    {"question": "地球的年龄大约是多少年？", "ground_truth": "45.4亿年"},
    {"question": "谁发明了印刷机？", "ground_truth": "约翰内斯·古腾堡"},
    {"question": "DNA中A与T配对，C与G配对，这叫什么规则？", "ground_truth": "碱基互补配对原则"},
    {"question": "谁是现代航空之父？", "ground_truth": "莱特兄弟"},
    {"question": "第一次工业革命发生在哪个国家？", "ground_truth": "英国"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古希腊神话中宙斯的妻子是谁？", "ground_truth": "赫拉"},
    {"question": "谁提出了板块构造学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "世界上最深的湖泊是哪一个？", "ground_truth": "贝加尔湖"},
    {"question": "谁发明了计算机鼠标？", "ground_truth": "道格·恩格尔巴特"},
    {"question": "光年是距离单位还是时间单位？", "ground_truth": "距离单位"},
    {"question": "谁是《蒙娜丽莎》的作者？", "ground_truth": "列奥纳多·达·芬奇"},
    {"question": "元素周期表中原子序数为6的元素是什么？", "ground_truth": "碳"},
    {"question": "谁发现了海王星？", "ground_truth": "约翰·伽勒"},
    {"question": "古中国汉朝的开国皇帝是谁？", "ground_truth": "刘邦"},
    {"question": "谁提出了进化论中的自然选择？", "ground_truth": "查尔斯·达尔文"},
    {"question": "世界上最长的山脉是哪一条？", "ground_truth": "安第斯山脉"},
    {"question": "谁发明了无线电？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "细菌属于哪一类生物？", "ground_truth": "原核生物"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "第一次登上珠峰的人是谁？", "ground_truth": "埃德蒙·希拉里和丹增·诺盖"},
    {"question": "谁发现了维生素C？", "ground_truth": "艾伯特· Szent-Györgyi"},
    {"question": "古埃及的文字叫什么？", "ground_truth": "象形文字"},
    {"question": "谁提出了狭义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最小的鸟是什么？", "ground_truth": "蜂鸟"},
    {"question": "谁发明了电报？", "ground_truth": "塞缪尔·莫尔斯"},
    {"question": "DNA的中文全称是什么？", "ground_truth": "脱氧核糖核酸"},
    {"question": "谁是现代物理学之父？", "ground_truth": "伽利略·伽利莱"},
    {"question": "古罗马最著名的皇帝是谁？", "ground_truth": "奥古斯都"},
    {"question": "谁发现了镭？", "ground_truth": "玛丽·居里"},
    {"question": "第一次世界大战的参战国主要分为哪两大集团？", "ground_truth": "同盟国和协约国"},
    {"question": "谁提出了细胞学说？", "ground_truth": "施莱登和施旺"},
    {"question": "世界上最长的河流是哪一条？", "ground_truth": "尼罗河"},
    {"question": "谁发明了自行车？", "ground_truth": "卡尔·冯·德莱斯"},
    {"question": "古中国唐朝最著名的诗人是谁？", "ground_truth": "李白"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的太平洋战场最著名战役是哪一场？", "ground_truth": "中途岛海战"},
    {"question": "谁是《战争与和平》的作者？", "ground_truth": "列夫·托尔斯泰"},
    {"question": "元素周期表中原子序数为26的元素是什么？", "ground_truth": "铁"},
    {"question": "谁发明了青霉素？", "ground_truth": "亚历山大·弗莱明"},
    {"question": "古希腊的民主制度起源于哪个城邦？", "ground_truth": "雅典"},
    {"question": "谁提出了玻尔模型？", "ground_truth": "尼尔斯·玻尔"},
    {"question": "世界上最高的瀑布是哪一个？", "ground_truth": "安赫尔瀑布"},
    {"question": "谁发明了蒸汽船？", "ground_truth": "罗伯特·富尔顿"},
    {"question": "DNA复制发生在细胞的哪个阶段？", "ground_truth": "分裂间期"},
    {"question": "谁是《神曲》的作者？", "ground_truth": "但丁"},
    {"question": "第一次鸦片战争的结束条约是什么？", "ground_truth": "南京条约"},
    {"question": "谁发现了海底扩张学说？", "ground_truth": "哈里·赫斯"},
    {"question": "古中国宋朝的著名科学家是谁？", "ground_truth": "沈括"},
    {"question": "谁提出了光的波动说？", "ground_truth": "克里斯蒂安·惠更斯"},
    {"question": "世界上最大的沙漠是哪一个？", "ground_truth": "撒哈拉沙漠"},
    {"question": "谁发明了留声机？", "ground_truth": "托马斯·爱迪生"},
    {"question": "细菌的细胞壁主要成分是什么？", "ground_truth": "肽聚糖"},
    {"question": "谁是《百年孤独》的作者？", "ground_truth": "加西亚·马尔克斯"},
    {"question": "谁发现了放射性？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "古罗马的货币叫什么？", "ground_truth": "第纳尔"},
    {"question": "谁提出了量子纠缠？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最深的海洋是哪一个？", "ground_truth": "太平洋"},
    {"question": "谁发明了飞机？", "ground_truth": "莱特兄弟"},
    {"question": "古埃及的太阳神叫什么？", "ground_truth": "拉"},
    {"question": "谁发现了大陆漂移？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的停战日是哪一天？", "ground_truth": "1918年11月11日"},
    {"question": "谁是《1984》的作者？", "ground_truth": "乔治·奥威尔"},
    {"question": "元素周期表中原子序数为8的元素是什么？", "ground_truth": "氧"},
    {"question": "谁发明了电视？", "ground_truth": "约翰·洛吉·贝尔德"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊的奥林匹克运动会起源于哪一年？", "ground_truth": "公元前776年"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最大的岛屿是哪一个？", "ground_truth": "格陵兰岛"},
    {"question": "谁发明了电报？", "ground_truth": "塞缪尔·莫尔斯"},
    {"question": "细菌的遗传物质是什么？", "ground_truth": "DNA"},
    {"question": "谁是《哈利·波特》的作者？", "ground_truth": "J.K. 罗琳"},
    {"question": "谁发现了中微子？", "ground_truth": "沃尔夫冈·泡利"},
    {"question": "古中国明朝的开国皇帝是谁？", "ground_truth": "朱元璋"},
    {"question": "谁提出了狭义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的围墙是哪一个？", "ground_truth": "中国长城"},
    {"question": "谁发明了无线电报？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "光合作用的光反应发生在叶绿体的哪个部位？", "ground_truth": "类囊体膜"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古埃及的金字塔主要用途是什么？", "ground_truth": "法老墓"},
    {"question": "谁提出了板块构造理论？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次工业革命的标志性发明是什么？", "ground_truth": "蒸汽机"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的欧洲战场结束于哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "世界上最古老的文明之一是哪一个？", "ground_truth": "苏美尔文明"},
    {"question": "谁发明了活字印刷术？", "ground_truth": "毕昇"},
    {"question": "细菌的形状主要分为哪几种？", "ground_truth": "球菌、杆菌、螺旋菌"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了放射性元素镭？", "ground_truth": "玛丽·居里"},
    {"question": "古希腊的民主制度创始人是谁？", "ground_truth": "克里斯提尼"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的珊瑚礁是哪一个？", "ground_truth": "大堡礁"},
    {"question": "谁发明了电影？", "ground_truth": "卢米埃尔兄弟"},
    {"question": "DNA的结构是双螺旋还是单螺旋？", "ground_truth": "双螺旋"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "谁发现了海底扩张？", "ground_truth": "哈里·赫斯"},
    {"question": "古中国春秋战国时期的百家争鸣主要发生在哪个时期？", "ground_truth": "春秋战国"},
    {"question": "谁提出了光量子假说？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的铁路是哪一条？", "ground_truth": "西伯利亚大铁路"},
    {"question": "谁发明了电灯泡？", "ground_truth": "托马斯·爱迪生"},
    {"question": "细菌的繁殖方式是什么？", "ground_truth": "二分裂"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古埃及的尼罗河主要作用是什么？", "ground_truth": "农业灌溉"},
    {"question": "谁提出了大陆漂移学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的凡尔赛和约签订于哪一年？", "ground_truth": "1919年"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古希腊的斯巴达城邦以什么闻名？", "ground_truth": "军事"},
    {"question": "谁提出了量子力学中的波函数？", "ground_truth": "埃尔温·薛定谔"},
    {"question": "世界上最大的湖泊是哪一个？", "ground_truth": "里海"},
    {"question": "谁发明了电话？", "ground_truth": "亚历山大·格雷厄姆·贝尔"},
    {"question": "DNA中胸腺嘧啶与什么碱基配对？", "ground_truth": "腺嘌呤"},
    {"question": "谁是《哈利·波特》的作者？", "ground_truth": "J.K. 罗琳"},
    {"question": "谁发现了放射性？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "古罗马的角斗士主要来自哪里？", "ground_truth": "奴隶和战俘"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的河流是哪一条？", "ground_truth": "尼罗河"},
    {"question": "谁发明了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "细菌的细胞膜主要成分是什么？", "ground_truth": "磷脂"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的诺曼底登陆发生在哪一年？", "ground_truth": "1944年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "古中国战国七雄是哪七个？", "ground_truth": "齐、楚、燕、韩、赵、魏、秦"},
    {"question": "谁提出了光电效应？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的洋是哪一个？", "ground_truth": "太平洋"},
    {"question": "谁发明了电报？", "ground_truth": "塞缪尔·莫尔斯"},
    {"question": "DNA的复制方式是什么？", "ground_truth": "半保留复制"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古埃及的法老主要埋葬在什么地方？", "ground_truth": "金字塔"},
    {"question": "谁提出了大陆漂移学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的停战协议是什么？", "ground_truth": "凡尔赛和约"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古希腊的雅典以什么闻名？", "ground_truth": "民主和哲学"},
    {"question": "谁提出了薛定谔方程？", "ground_truth": "埃尔温·薛定谔"},
    {"question": "世界上最大的沙漠是哪一个？", "ground_truth": "撒哈拉沙漠"},
    {"question": "谁发明了飞机？", "ground_truth": "莱特兄弟"},
    {"question": "细菌的遗传物质主要存在于哪里？", "ground_truth": "拟核"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了放射性元素？", "ground_truth": "玛丽·居里"},
    {"question": "古罗马的元老院主要作用是什么？", "ground_truth": "立法和咨询"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的山脉是哪一条？", "ground_truth": "安第斯山脉"},
    {"question": "谁发明了无线电？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "DNA的双螺旋结构是由谁发现的？", "ground_truth": "詹姆斯·沃森和弗朗西斯·克里克"},
    {"question": "谁是《哈利·波特》的作者？", "ground_truth": "J.K. 罗琳"},
    {"question": "谁发现了中微子？", "ground_truth": "沃尔夫冈·泡利"},
    {"question": "古中国秦朝的统一时间是哪一年？", "ground_truth": "公元前221年"},
    {"question": "谁提出了量子纠缠？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的岛屿是哪一个？", "ground_truth": "格陵兰岛"},
    {"question": "谁发明了电灯？", "ground_truth": "托马斯·爱迪生"},
    {"question": "细菌的细胞壁主要成分是什么？", "ground_truth": "肽聚糖"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的结束时间是哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "古中国汉朝的丝绸之路起源于哪个城市？", "ground_truth": "长安"},
    {"question": "谁提出了光量子假说？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最深的湖泊是哪一个？", "ground_truth": "贝加尔湖"},
    {"question": "谁发明了电话？", "ground_truth": "亚历山大·格雷厄姆·贝尔"},
    {"question": "DNA中鸟嘌呤与什么碱基配对？", "ground_truth": "胞嘧啶"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古埃及的尼罗河泛滥主要带来什么？", "ground_truth": "肥沃土壤"},
    {"question": "谁提出了板块构造学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的导火索是什么？", "ground_truth": "萨拉热窝事件"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了放射性？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "古希腊的斯巴达以什么闻名？", "ground_truth": "军事训练"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最长的铁路是哪一条？", "ground_truth": "西伯利亚大铁路"},
    {"question": "谁发明了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "细菌的繁殖方式是什么？", "ground_truth": "二分裂"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古罗马的凯撒大帝被刺杀于哪一年？", "ground_truth": "公元前44年"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的洋是哪一个？", "ground_truth": "太平洋"},
    {"question": "谁发明了飞机？", "ground_truth": "莱特兄弟"},
    {"question": "DNA的结构发现者是？", "ground_truth": "詹姆斯·沃森和弗朗西斯·克里克"},
    {"question": "谁是《哈利·波特》的作者？", "ground_truth": "J.K. 罗琳"},
    {"question": "谁发现了镭？", "ground_truth": "玛丽·居里"},
    {"question": "古中国明朝的郑和下西洋主要目的是什么？", "ground_truth": "宣扬国威"},
    {"question": "谁提出了量子力学中的波函数？", "ground_truth": "埃尔温·薛定谔"},
    {"question": "世界上最大的珊瑚礁是哪一个？", "ground_truth": "大堡礁"},
    {"question": "谁发明了电影？", "ground_truth": "卢米埃尔兄弟"},
    {"question": "细菌的遗传物质主要存在于哪里？", "ground_truth": "拟核"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的太平洋战场结束于哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "古中国秦朝的长城主要作用是什么？", "ground_truth": "防御匈奴"},
    {"question": "谁提出了光电效应？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的山脉是哪一条？", "ground_truth": "安第斯山脉"},
    {"question": "谁发明了无线电？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊的奥林匹克运动会每几年举办一次？", "ground_truth": "4年"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最大的岛屿是哪一个？", "ground_truth": "格陵兰岛"},
    {"question": "谁发明了电灯？", "ground_truth": "托马斯·爱迪生"},
    {"question": "细菌的细胞膜主要成分是什么？", "ground_truth": "磷脂"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古埃及的象形文字主要刻在什么材料上？", "ground_truth": "纸草"},
    {"question": "谁提出了大陆漂移学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的停战日是哪一天？", "ground_truth": "1918年11月11日"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了放射性？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "古希腊的雅典以什么闻名？", "ground_truth": "民主和哲学"},
    {"question": "谁提出了薛定谔方程？", "ground_truth": "埃尔温·薛定谔"},
    {"question": "世界上最大的沙漠是哪一个？", "ground_truth": "撒哈拉沙漠"},
    {"question": "谁发明了飞机？", "ground_truth": "莱特兄弟"},
    {"question": "细菌的繁殖方式是什么？", "ground_truth": "二分裂"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古罗马的凯撒大帝被刺杀于哪一年？", "ground_truth": "公元前44年"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的洋是哪一个？", "ground_truth": "太平洋"},
    {"question": "谁发明了无线电？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊的奥林匹克运动会起源于哪一年？", "ground_truth": "公元前776年"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最长的铁路是哪一条？", "ground_truth": "西伯利亚大铁路"},
    {"question": "谁发明了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "细菌的细胞壁主要成分是什么？", "ground_truth": "肽聚糖"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的结束时间是哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "古中国汉朝的丝绸之路起源于哪个城市？", "ground_truth": "长安"},
    {"question": "谁提出了光量子假说？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最深的湖泊是哪一个？", "ground_truth": "贝加尔湖"},
    {"question": "谁发明了电话？", "ground_truth": "亚历山大·格雷厄姆·贝尔"},
    {"question": "DNA中胸腺嘧啶与什么碱基配对？", "ground_truth": "腺嘌呤"},
    {"question": "谁是《红楼梦》的作者？", "ground_truth": "曹雪芹"},
    {"question": "谁发现了X射线？", "ground_truth": "威廉·伦琴"},
    {"question": "古埃及的尼罗河泛滥主要带来什么？", "ground_truth": "肥沃土壤"},
    {"question": "谁提出了板块构造学说？", "ground_truth": "阿尔弗雷德·魏格纳"},
    {"question": "第一次世界大战的导火索是什么？", "ground_truth": "萨拉热窝事件"},
    {"question": "谁是《三国演义》的作者？", "ground_truth": "罗贯中"},
    {"question": "谁发现了放射性？", "ground_truth": "亨利·贝克勒尔"},
    {"question": "古希腊的斯巴达以什么闻名？", "ground_truth": "军事训练"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最长的铁路是哪一条？", "ground_truth": "西伯利亚大铁路"},
    {"question": "谁发明了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "细菌的繁殖方式是什么？", "ground_truth": "二分裂"},
    {"question": "谁是《西游记》的作者？", "ground_truth": "吴承恩"},
    {"question": "谁发现了中子？", "ground_truth": "詹姆斯·查德威克"},
    {"question": "古罗马的凯撒大帝被刺杀于哪一年？", "ground_truth": "公元前44年"},
    {"question": "谁提出了广义相对论？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最大的洋是哪一个？", "ground_truth": "太平洋"},
    {"question": "谁发明了飞机？", "ground_truth": "莱特兄弟"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊的奥林匹克运动会每几年举办一次？", "ground_truth": "4年"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最大的岛屿是哪一个？", "ground_truth": "格陵兰岛"},
    {"question": "谁发明了电灯？", "ground_truth": "托马斯·爱迪生"},
    {"question": "细菌的细胞膜主要成分是什么？", "ground_truth": "磷脂"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的太平洋战场结束于哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"},
    {"question": "古中国战国七雄是哪七个？", "ground_truth": "齐、楚、燕、韩、赵、魏、秦"},
    {"question": "谁提出了光电效应？", "ground_truth": "阿尔伯特·爱因斯坦"},
    {"question": "世界上最长的山脉是哪一条？", "ground_truth": "安第斯山脉"},
    {"question": "谁发明了无线电？", "ground_truth": "古列尔莫·马可尼"},
    {"question": "DNA的双螺旋结构发现于哪一年？", "ground_truth": "1953年"},
    {"question": "古希腊的奥林匹克运动会起源于哪一年？", "ground_truth": "公元前776年"},
    {"question": "谁提出了不确定性原理？", "ground_truth": "沃纳·海森堡"},
    {"question": "世界上最长的铁路是哪一条？", "ground_truth": "西伯利亚大铁路"},
    {"question": "谁发明了蒸汽机？", "ground_truth": "詹姆斯·瓦特"},
    {"question": "细菌的细胞壁主要成分是什么？", "ground_truth": "肽聚糖"},
    {"question": "谁是《水浒传》的作者？", "ground_truth": "施耐庵"},
    {"question": "谁发现了电子？", "ground_truth": "J.J. 汤姆逊"},
    {"question": "第二次世界大战的结束时间是哪一年？", "ground_truth": "1945年"},
    {"question": "谁提出了量子论？", "ground_truth": "马克斯·普朗克"}
]

print(f" Loading {len(QUESTIONS)} issue")

# model
MODELS = [
    {"name": "1.5B", "id": "unsloth/Qwen2.5-1.5B-Instruct"},
    {"name": "7B",   "id": "unsloth/Qwen2.5-7B-Instruct"}
]

def load_model(model_id):
    print(f"\nLoading {model_id} ...")
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_id,
        max_seq_length=2048,
        dtype=None,
        load_in_4bit=True,
        trust_remote_code=True
    )
    FastLanguageModel.for_inference(model)
    print(f" {model_id} loading complete")
    return model, tokenizer

def generate_response(model, tokenizer, question):
    messages = [
        {"role": "system", "content": "你是一个诚实、准确的AI助手。请用简洁语言回答问题，不要编造事实。"},
        {"role": "user", "content": question}
    ]
    inputs = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt").to("cuda")

    start_time = time.time()
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=256,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.1,
        do_sample=True
    )
    end_time = time.time()

    response = tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True).strip()
    output_tokens = len(outputs[0]) - len(inputs[0])
    speed = output_tokens / (end_time - start_time) if (end_time - start_time) > 0 else 0

    del outputs, inputs
    torch.cuda.empty_cache()
    gc.collect()

    return response, output_tokens, speed

results = {}

for model_info in MODELS:
    model, tokenizer = load_model(model_info["id"])
    responses = []
    lengths = []
    speeds = []

    print(f"\n Start test {model_info['name']} model（365 questions）...")
    for i, q in enumerate(QUESTIONS):
        print(f"   question {i+1}/365: {q['question'][:60]}...")
        resp, length, speed = generate_response(model, tokenizer, q['question'])
        responses.append(resp)
        lengths.append(length)
        speeds.append(speed)
        print(f"      → length: {length} tokens | rate: {speed:.1f} tokens/s")

    results[model_info["name"]] = {
        "responses": responses,
        "avg_length": mean(lengths),
        "avg_speed": mean(speeds)
    }

    del model, tokenizer
    gc.collect()
    torch.cuda.empty_cache()

# 评判部分
print("\n 进行事实准确率和幻觉率评判")
judge_model, judge_tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Qwen2.5-1.5B-Instruct",
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
    trust_remote_code=True
)
FastLanguageModel.for_inference(judge_model)

def judge_response(question, ground_truth, response):
    judge_prompt = f"""你是一个严格的事实检查员。
问题: {question}
正确参考答案: {ground_truth}
模型回答: {response}

请只输出JSON，不要任何其他文字：
{{"事实准确率": 数值（0-100）, "幻觉率": 数值（0-100）}}"""

    inputs = judge_tokenizer.apply_chat_template(
        [{"role": "user", "content": judge_prompt}],
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to("cuda")

    outputs = judge_model.generate(inputs, max_new_tokens=120, temperature=0.1, do_sample=False)
    judge_text = judge_tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True)

    try:
        json_match = re.search(r'\{.*?\}', judge_text, re.DOTALL)
        score_dict = json.loads(json_match.group(0))
        acc = float(score_dict.get("事实准确率", 50))
        hallu = float(score_dict.get("幻觉率", 50))
    except:
        acc = hallu = 50

    del outputs, inputs
    torch.cuda.empty_cache()
    return acc, hallu

for model_name in ["1.5B", "7B"]:
    print(f"\n正在评判 {model_name} 的365个回答...")
    acc_scores = []
    hallu_scores = []
    for i, resp in enumerate(results[model_name]["responses"]):
        q = QUESTIONS[i]["question"]
        gt = QUESTIONS[i]["ground_truth"]
        acc, hallu = judge_response(q, gt, resp)
        acc_scores.append(acc)
        hallu_scores.append(hallu)
        if (i + 1) % 20 == 0:
            print(f"   已评判 {i+1}/365 个问题")

    results[model_name]["fact_accuracy"] = mean(acc_scores)
    results[model_name]["hallucination_rate"] = mean(hallu_scores)

del judge_model, judge_tokenizer
gc.collect()
torch.cuda.empty_cache()

# 输出表格 + 曲线 + 结论 + 所有回答
print("\n" + "="*80)
print(" 365个问题完整实验结果")

data = {
    "模型规模": ["1.5B", "7B"],
    "幻觉率 (%)": [round(results["1.5B"]["hallucination_rate"], 2), round(results["7B"]["hallucination_rate"], 2)],
    "事实准确率 (%)": [round(results["1.5B"]["fact_accuracy"], 2), round(results["7B"]["fact_accuracy"], 2)],
    "平均响应长度 (tokens)": [round(results["1.5B"]["avg_length"], 1), round(results["7B"]["avg_length"], 1)],
    "平均推理速度 (tokens/s)": [round(results["1.5B"]["avg_speed"], 1), round(results["7B"]["avg_speed"], 1)]
}
df = pd.DataFrame(data)
print(df.to_string(index=False))

plt.figure(figsize=(8, 5))
scales = [1.5, 7.0]
hallu_rates = [results["1.5B"]["hallucination_rate"], results["7B"]["hallucination_rate"]]
plt.plot(scales, hallu_rates, marker='o', linestyle='-', color='red', linewidth=2, markersize=8)
plt.xlabel("Model size (Billion Parameters)")
plt.ylabel("Hallucination rate (%)")
plt.title("Qwen2.5 Model Size vs. Illusion Rate (365 Questions)")
plt.grid(True)
plt.show()

print("\n 结论：")
if results["7B"]["hallucination_rate"] < results["1.5B"]["hallucination_rate"] - 3:
    print(" 规模越大越稳！7B 幻觉率明显更低，事实准确率更高。")
elif results["7B"]["hallucination_rate"] > results["1.5B"]["hallucination_rate"] + 3:
    print("  规模越大反而更会编！1.5B 更稳健。")
else:
    print(" 两个规模表现接近，7B 略有优势。")

#  完整打印所有365个回答
print("\n" + "="*80)
print(" 1.5B 模型对所有365个问题的完整回答")
for i, q in enumerate(QUESTIONS):
    print(f"\n问题 {i+1}: {q['question']}")
    print(f"1.5B 回答: {results['1.5B']['responses'][i]}")
    print("-" * 60)

print("\n" + "="*80)
print(" 7B 模型对所有365个问题的完整回答")
for i, q in enumerate(QUESTIONS):
    print(f"\n问题 {i+1}: {q['question']}")
    print(f"7B 回答: {results['7B']['responses'][i]}")
    print("-" * 60)
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 86.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 94.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 17.4 MB/s eta 0:00:00
# ...
